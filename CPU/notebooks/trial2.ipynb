# %%
import sys
# !{sys.executable} -m pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.2.0-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\avilasha\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (2.3.5)
# Requirement already satisfied: scipy in c:\users\avilasha\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (1.17.0)
# Downloading xgboost-3.2.0-py3-none-win_amd64.whl (101.7 MB)
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.8/101.7 MB 4.8 MB/s eta 0:00:21
#     --------------------------------------- 1.6/101.7 MB 3.7 MB/s eta 0:00:28
#     --------------------------------------- 2.4/101.7 MB 3.9 MB/s eta 0:00:26
#    - -------------------------------------- 3.1/101.7 MB 3.8 MB/s eta 0:00:27
#    - -------------------------------------- 3.9/101.7 MB 3.9 MB/s eta 0:00:26
#    - -------------------------------------- 4.7/101.7 MB 3.8 MB/s eta 0:00:26
#    -- ------------------------------------- 5.5/101.7 MB 3.8 MB/s eta 0:00:26
#    -- ------------------------------------- 6.0/101.7 MB 3.6 MB/s eta 0:00:27
#    -- ------------------------------------- 6.3/101.7 MB 3.6 MB/s eta 0:00:27
#    -- ------------------------------------- 7.1/101.7 MB 3.5 MB/s eta 0:00:28
#    --- ------------------------------------ 8.1/101.7 MB 3.5 MB/s eta 0:00:27
#    --- ------------------------------------ 8.9/101.7 MB 3.6 MB/s eta 0:00:26
#    --- ------------------------------------ 9.7/101.7 MB 3.6 MB/s eta 0:00:26
#    ---- ----------------------------------- 10.5/101.7 MB 3.7 MB/s eta 0:00:25
#    ---- ----------------------------------- 11.0/101.7 MB 3.6 MB/s eta 0:00:26
#    ---- ----------------------------------- 11.8/101.7 MB 3.6 MB/s eta 0:00:25
#    ---- ----------------------------------- 12.6/101.7 MB 3.6 MB/s eta 0:00:25
#    ----- ---------------------------------- 13.4/101.7 MB 3.6 MB/s eta 0:00:25
#    ----- ---------------------------------- 14.2/101.7 MB 3.6 MB/s eta 0:00:25
#    ----- ---------------------------------- 14.9/101.7 MB 3.7 MB/s eta 0:00:24
#    ------ --------------------------------- 15.7/101.7 MB 3.7 MB/s eta 0:00:24
#    ------ --------------------------------- 16.5/101.7 MB 3.6 MB/s eta 0:00:24
#    ------ --------------------------------- 17.3/101.7 MB 3.6 MB/s eta 0:00:24
#    ------- -------------------------------- 18.4/101.7 MB 3.7 MB/s eta 0:00:23
#    ------- -------------------------------- 19.1/101.7 MB 3.7 MB/s eta 0:00:23
#    ------- -------------------------------- 19.9/101.7 MB 3.7 MB/s eta 0:00:22
#    -------- ------------------------------- 20.7/101.7 MB 3.7 MB/s eta 0:00:22
#    -------- ------------------------------- 21.8/101.7 MB 3.8 MB/s eta 0:00:22
#    -------- ------------------------------- 22.3/101.7 MB 3.7 MB/s eta 0:00:22
#    --------- ------------------------------ 23.1/101.7 MB 3.8 MB/s eta 0:00:21
#    --------- ------------------------------ 24.1/101.7 MB 3.8 MB/s eta 0:00:21
#    --------- ------------------------------ 24.6/101.7 MB 3.8 MB/s eta 0:00:21
#    ---------- ----------------------------- 25.4/101.7 MB 3.8 MB/s eta 0:00:21
#    ---------- ----------------------------- 26.2/101.7 MB 3.8 MB/s eta 0:00:21
#    ---------- ----------------------------- 27.0/101.7 MB 3.8 MB/s eta 0:00:20
#    ---------- ----------------------------- 27.5/101.7 MB 3.8 MB/s eta 0:00:20
#    ----------- ---------------------------- 28.0/101.7 MB 3.7 MB/s eta 0:00:20
#    ----------- ---------------------------- 28.6/101.7 MB 3.7 MB/s eta 0:00:20
#    ----------- ---------------------------- 29.1/101.7 MB 3.6 MB/s eta 0:00:21
#    ----------- ---------------------------- 29.9/101.7 MB 3.6 MB/s eta 0:00:20
#    ----------- ---------------------------- 30.4/101.7 MB 3.6 MB/s eta 0:00:20
#    ------------ --------------------------- 30.9/101.7 MB 3.6 MB/s eta 0:00:20
#    ------------ --------------------------- 31.7/101.7 MB 3.6 MB/s eta 0:00:20
#    ------------ --------------------------- 32.8/101.7 MB 3.6 MB/s eta 0:00:20
#    ------------- -------------------------- 33.6/101.7 MB 3.6 MB/s eta 0:00:19
#    ------------- -------------------------- 34.3/101.7 MB 3.6 MB/s eta 0:00:19
#    ------------- -------------------------- 35.4/101.7 MB 3.7 MB/s eta 0:00:19
#    -------------- ------------------------- 36.2/101.7 MB 3.7 MB/s eta 0:00:18
#    -------------- ------------------------- 36.7/101.7 MB 3.7 MB/s eta 0:00:18
#    -------------- ------------------------- 37.7/101.7 MB 3.7 MB/s eta 0:00:18
#    --------------- ------------------------ 38.5/101.7 MB 3.7 MB/s eta 0:00:18
#    --------------- ------------------------ 39.1/101.7 MB 3.7 MB/s eta 0:00:18
#    --------------- ------------------------ 39.6/101.7 MB 3.7 MB/s eta 0:00:17
#    --------------- ------------------------ 40.1/101.7 MB 3.6 MB/s eta 0:00:17
#    ---------------- ----------------------- 40.9/101.7 MB 3.6 MB/s eta 0:00:17
#    ---------------- ----------------------- 41.7/101.7 MB 3.6 MB/s eta 0:00:17
#    ---------------- ----------------------- 42.2/101.7 MB 3.6 MB/s eta 0:00:17
#    ---------------- ----------------------- 43.0/101.7 MB 3.6 MB/s eta 0:00:17
#    ----------------- ---------------------- 44.0/101.7 MB 3.6 MB/s eta 0:00:16
#    ----------------- ---------------------- 44.6/101.7 MB 3.6 MB/s eta 0:00:16
#    ----------------- ---------------------- 45.1/101.7 MB 3.6 MB/s eta 0:00:16
#    ------------------ --------------------- 46.4/101.7 MB 3.6 MB/s eta 0:00:16
#    ------------------ --------------------- 46.9/101.7 MB 3.6 MB/s eta 0:00:16
#    ------------------ --------------------- 47.4/101.7 MB 3.6 MB/s eta 0:00:15
#    ------------------- -------------------- 48.5/101.7 MB 3.6 MB/s eta 0:00:15
#    ------------------- -------------------- 48.8/101.7 MB 3.6 MB/s eta 0:00:15
#    ------------------- -------------------- 49.5/101.7 MB 3.6 MB/s eta 0:00:15
#    ------------------- -------------------- 50.1/101.7 MB 3.6 MB/s eta 0:00:15
#    -------------------- ------------------- 50.9/101.7 MB 3.6 MB/s eta 0:00:15
#    -------------------- ------------------- 51.4/101.7 MB 3.6 MB/s eta 0:00:15
#    -------------------- ------------------- 51.9/101.7 MB 3.5 MB/s eta 0:00:15
#    -------------------- ------------------- 52.4/101.7 MB 3.5 MB/s eta 0:00:14
#    -------------------- ------------------- 53.2/101.7 MB 3.5 MB/s eta 0:00:14
#    --------------------- ------------------ 54.0/101.7 MB 3.5 MB/s eta 0:00:14
#    --------------------- ------------------ 54.8/101.7 MB 3.5 MB/s eta 0:00:14
#    --------------------- ------------------ 55.6/101.7 MB 3.6 MB/s eta 0:00:13
#    ---------------------- ----------------- 56.1/101.7 MB 3.6 MB/s eta 0:00:13
#    ---------------------- ----------------- 57.1/101.7 MB 3.6 MB/s eta 0:00:13
#    ---------------------- ----------------- 57.9/101.7 MB 3.6 MB/s eta 0:00:13
#    ----------------------- ---------------- 58.7/101.7 MB 3.6 MB/s eta 0:00:13
#    ----------------------- ---------------- 59.8/101.7 MB 3.6 MB/s eta 0:00:12
#    ------------------------ --------------- 61.1/101.7 MB 3.6 MB/s eta 0:00:12
#    ------------------------ --------------- 61.9/101.7 MB 3.6 MB/s eta 0:00:11
#    ------------------------ --------------- 62.7/101.7 MB 3.6 MB/s eta 0:00:11
#    ------------------------- -------------- 63.7/101.7 MB 3.6 MB/s eta 0:00:11
#    ------------------------- -------------- 64.5/101.7 MB 3.6 MB/s eta 0:00:11
#    ------------------------- -------------- 65.5/101.7 MB 3.7 MB/s eta 0:00:10
#    ------------------------- -------------- 66.1/101.7 MB 3.6 MB/s eta 0:00:10
#    -------------------------- ------------- 66.6/101.7 MB 3.6 MB/s eta 0:00:10
#    -------------------------- ------------- 67.1/101.7 MB 3.6 MB/s eta 0:00:10
#    -------------------------- ------------- 67.6/101.7 MB 3.6 MB/s eta 0:00:10
#    --------------------------- ------------ 68.7/101.7 MB 3.6 MB/s eta 0:00:10
#    --------------------------- ------------ 69.5/101.7 MB 3.6 MB/s eta 0:00:09
#    --------------------------- ------------ 70.5/101.7 MB 3.6 MB/s eta 0:00:09
#    ---------------------------- ----------- 71.6/101.7 MB 3.7 MB/s eta 0:00:09
#    ---------------------------- ----------- 72.4/101.7 MB 3.7 MB/s eta 0:00:09
#    ---------------------------- ----------- 73.7/101.7 MB 3.7 MB/s eta 0:00:08
#    ----------------------------- ---------- 74.7/101.7 MB 3.7 MB/s eta 0:00:08
#    ----------------------------- ---------- 75.5/101.7 MB 3.7 MB/s eta 0:00:08
#    ------------------------------ --------- 76.3/101.7 MB 3.7 MB/s eta 0:00:07
#    ------------------------------ --------- 77.1/101.7 MB 3.7 MB/s eta 0:00:07
#    ------------------------------ --------- 77.6/101.7 MB 3.7 MB/s eta 0:00:07
#    ------------------------------ --------- 78.4/101.7 MB 3.7 MB/s eta 0:00:07
#    ------------------------------- -------- 79.2/101.7 MB 3.7 MB/s eta 0:00:07
#    ------------------------------- -------- 80.0/101.7 MB 3.7 MB/s eta 0:00:06
#    ------------------------------- -------- 80.7/101.7 MB 3.7 MB/s eta 0:00:06
#    -------------------------------- ------- 81.5/101.7 MB 3.7 MB/s eta 0:00:06
#    -------------------------------- ------- 82.8/101.7 MB 3.7 MB/s eta 0:00:06
#    -------------------------------- ------- 83.6/101.7 MB 3.7 MB/s eta 0:00:05
#    --------------------------------- ------ 84.1/101.7 MB 3.7 MB/s eta 0:00:05
#    --------------------------------- ------ 84.4/101.7 MB 3.7 MB/s eta 0:00:05
#    --------------------------------- ------ 85.7/101.7 MB 3.7 MB/s eta 0:00:05
#    ---------------------------------- ----- 87.3/101.7 MB 3.7 MB/s eta 0:00:04
#    ---------------------------------- ----- 88.3/101.7 MB 3.8 MB/s eta 0:00:04
#    ----------------------------------- ---- 89.1/101.7 MB 3.8 MB/s eta 0:00:04
#    ----------------------------------- ---- 89.9/101.7 MB 3.8 MB/s eta 0:00:04
#    ----------------------------------- ---- 90.2/101.7 MB 3.8 MB/s eta 0:00:04
#    ----------------------------------- ---- 91.2/101.7 MB 3.8 MB/s eta 0:00:03
#    ------------------------------------ --- 92.5/101.7 MB 3.8 MB/s eta 0:00:03
#    ------------------------------------ --- 93.3/101.7 MB 3.8 MB/s eta 0:00:03
#    ------------------------------------- -- 94.4/101.7 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 95.2/101.7 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 95.9/101.7 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 96.5/101.7 MB 3.8 MB/s eta 0:00:02
#    -------------------------------------- - 97.5/101.7 MB 3.8 MB/s eta 0:00:02
#    -------------------------------------- - 98.8/101.7 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  99.6/101.7 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  100.4/101.7 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  101.4/101.7 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 101.7/101.7 MB 3.8 MB/s  0:00:27
# Installing collected packages: xgboost
# Successfully installed xgboost-3.2.0
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Imports
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)
import matplotlib.pyplot as plt

# %%
# Loading and timestamp conversion
df = pd.read_csv(
    r"C:\Users\Avilasha\Desktop\CPU_Predictive_Maintenance\CPU\data\Processed\cpu_baseline.csv"
)
df['ts'] = pd.to_datetime(
    df['ts'],
    format='mixed',
    utc=True
)
df = df.sort_values(
    ['host_id', 'ts']
)
df.head()
# Out:
#        id                               ts  host_id  cpu_usage_pct  \
# 49502  34 2026-04-02 12:44:09.710000+00:00        1            4.0
# 49503  37 2026-04-02 12:46:02.041000+00:00        1            4.0
# 49504  40 2026-04-02 12:47:28.840000+00:00        1            4.0
# 49505  43 2026-04-02 12:49:08.515000+00:00        1            6.0
# 49506  46 2026-04-02 12:51:17.199000+00:00        1            4.0
#
#        memory_usage_pct  power_kw  status     hostName  inlet_temp_c  \
# 49502              74.0     0.221  Normal  10.10.10.65            19
# 49503              74.0     0.220  Normal  10.10.10.65            21
# 49504              74.0     0.220  Normal  10.10.10.65            19
# 49505              74.0     0.221  Normal  10.10.10.65            21
# 49506              74.0     0.222  Normal  10.10.10.65            19
#
#        cpu_temp_c  ...  thermal_gradient  temp_rate_of_change  \
# 49502          38  ...                19                  0.0
# 49503          38  ...                17                  0.0
# 49504          38  ...                19                  0.0
# 49505          38  ...                17                  0.0
# 49506          38  ...                19                  0.0
#
#        temp_roll_mean_12  cpu_per_kw  temp_per_cpu  resource_stress_index  \
# 49502               38.0   18.099548      7.600000                   39.0
# 49503               38.0   18.181818      7.600000                   39.0
# 49504               38.0   18.181818      7.600000                   39.0
# 49505               38.0   27.149321      5.428571                   40.0
# 49506               38.0   18.018018      7.600000                   39.0
#
#        timestamp_display  hour_of_day  day_of_week  is_weekend
# 49502   02-04-2026 12:44           12            3           0
# 49503   02-04-2026 12:46           12            3           0
# 49504   02-04-2026 12:47           12            3           0
# 49505   02-04-2026 12:49           12            3           0
# 49506   02-04-2026 12:51           12            3           0
#
# [5 rows x 31 columns]

# %%
# Select one server
SERVER_ID = 1
df = df[
    df['host_id'] == SERVER_ID
].copy()

print(df.shape)
# Out:
# (24750, 31)

# %%
# Create 12 historical CPU Lags
for lag in range(1, 13):
    
    df[f'cpu_lag_{lag}'] = (
        df['cpu_usage_pct']
        .shift(lag)
    )

# Remove missing rows
df = df.dropna()
print(df.shape)
# Out:
# (24738, 41)

# %%
# Features
FEATURES = [
    'cpu_lag_1',
    'cpu_lag_2',
    'cpu_lag_3',
    'cpu_lag_4',
    'cpu_lag_5',
    'cpu_lag_6',
    'cpu_lag_7',
    'cpu_lag_8',
    'cpu_lag_9',
    'cpu_lag_10',
    'cpu_lag_11',
    'cpu_lag_12',

    'memory_usage_pct',

    'power_kw',

    'cpu_temp_c',
    'inlet_temp_c',

    'cpu_change',
    'cpu_roll_mean_3',
    'cpu_volatility',

    'resource_stress_index',

    'hour_of_day',
    'day_of_week',
    'is_weekend'
]

TARGET = 'cpu_usage_pct'

# %%
# Train-test split
split_index = int(
    len(df) * 0.8
)

train_df = df.iloc[:split_index]

test_df = df.iloc[split_index:]

print(train_df.shape)
print(test_df.shape)

# create X and y
X_train = train_df[FEATURES]
y_train = train_df[TARGET]
X_test = test_df[FEATURES]
y_test = test_df[TARGET]
# Out:
# (19790, 41)
# (4948, 41)

# %%
# Train XGBoost
model = XGBRegressor(
    n_estimators=500,
    max_depth=8,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)
model.fit(
    X_train,
    y_train
)

# Predict
predictions = model.predict(
    X_test
)

# %%
# Metrics
mae = mean_absolute_error(
    y_test,
    predictions
)
rmse = np.sqrt(
    mean_squared_error(
        y_test,
        predictions
    )
)
r2 = r2_score(
    y_test,
    predictions
)
print("MAE :", mae)
print("RMSE:", rmse)
print("R²  :", r2)
# Out:
# MAE : 0.8124934245837534
# RMSE: 1.4044155704425356
# R²  : 0.3266090953105574

# %%
# Results dataframe
results = pd.DataFrame({

    'Timestamp': test_df['ts'],
    'Actual': y_test,
    'Predicted': predictions
})
results.head(10)
# Out:
#                              Timestamp  Actual  Predicted
# 69304 2026-05-25 00:14:17.159000+00:00     2.0   2.003962
# 69305 2026-05-25 00:19:20.486000+00:00     1.0   0.993482
# 69306 2026-05-25 00:24:18.700000+00:00     2.0   2.001049
# 69307 2026-05-25 00:29:17.056000+00:00     4.0   4.029106
# 69308 2026-05-25 00:34:19.451000+00:00     3.0   3.022935
# 69309 2026-05-25 00:39:16.931000+00:00     4.0   4.058516
# 69310 2026-05-25 00:44:17.214000+00:00     3.0   3.084176
# 69311 2026-05-25 00:49:19.631000+00:00     3.0   3.026309
# 69312 2026-05-25 00:54:18.602000+00:00     3.0   3.003773
# 69313 2026-05-25 00:59:16.743000+00:00     3.0   3.034074

# %%
# Actual vs Predicted plot
plt.figure(
    figsize=(18,6)
)
plt.plot(
    results['Timestamp'],
    results['Actual'],
    label='Actual'
)
plt.plot(
    results['Timestamp'],
    results['Predicted'],
    label='Predicted'
)
plt.legend()
plt.title(
    "CPU Usage Forecast - XGBoost"
)

plt.show()

# %%
# get the hostname
SERVER_NAME = df['hostName'].iloc[0]
print(SERVER_NAME)

# Plot
import matplotlib.pyplot as plt
fig, axes = plt.subplots(
    3,
    1,
    figsize=(18, 12),
    sharex=True
)
# -----------------------------
# Actual CPU
# -----------------------------
axes[0].plot(
    results['Timestamp'],
    results['Actual']
)
axes[0].set_title(
    f'{SERVER_NAME} | Actual CPU Usage'
)
axes[0].set_ylabel(
    'CPU Usage (%)'
)
axes[0].grid(True)
# -----------------------------
# Predicted CPU
# -----------------------------
axes[1].plot(
    results['Timestamp'],
    results['Predicted']
)
axes[1].set_title(
    f'{SERVER_NAME} | Predicted CPU Usage'
)
axes[1].set_ylabel(
    'CPU Usage (%)'
)
axes[1].grid(True)
# -----------------------------
# Actual vs Predicted
# -----------------------------
axes[2].plot(
    results['Timestamp'],
    results['Actual'],
    label='Actual'
)
axes[2].plot(
    results['Timestamp'],
    results['Predicted'],
    label='Predicted'
)
axes[2].set_title(
    f'{SERVER_NAME} | Actual vs Predicted CPU Usage'
)
axes[2].set_ylabel(
    'CPU Usage (%)'
)
axes[2].set_xlabel(
    'Timestamp'
)
axes[2].legend()
axes[2].grid(True)
plt.tight_layout()

plt.show()
# Out:
# 10.10.10.65

# %% [markdown]
# PREDICTING NEXT 1 HOUR USING PREVIOUS 6 HOURS

# %%
# create future targets
FORECAST_HORIZON = 12
for step in range(1, FORECAST_HORIZON + 1):

    df[f'target_t+{step}'] = (
        df['cpu_usage_pct']
        .shift(-step)
    )

# Remove NaNs
df_multi = df.dropna().copy()
print(df_multi.shape)

# create target matrix
TARGETS = [
    f'target_t+{i}'
    for i in range(1, FORECAST_HORIZON + 1)
]
TARGETS
# Out:
# (24666, 113)
# ['target_t+1',
#  'target_t+2',
#  'target_t+3',
#  'target_t+4',
#  'target_t+5',
#  'target_t+6',
#  'target_t+7',
#  'target_t+8',
#  'target_t+9',
#  'target_t+10',
#  'target_t+11',
#  'target_t+12']

# %%
CPU_LAGS = [
    f'cpu_lag_{i}'
    for i in range(1,73)
]
FEATURES = (
    CPU_LAGS +
    [
        'memory_usage_pct',

        'power_kw',

        'cpu_temp_c',
        'inlet_temp_c',

        'cpu_change',
        'cpu_roll_mean_3',
        'cpu_volatility',

        'resource_stress_index',

        'hour_of_day',
        'day_of_week',
        'is_weekend'
    ]
)
# Out:
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (
# C:\Users\Avilasha\AppData\Local\Temp\ipykernel_27540\1932019996.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cpu_lag_{lag}'] = (

# %%
# Train-test split
split_index = int(
    len(df_multi) * 0.8
)
train_df = df_multi.iloc[:split_index]
test_df = df_multi.iloc[split_index:]

print(train_df.shape)
print(test_df.shape)
# Out:
# (19732, 113)
# (4934, 113)

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (19732, 23)
# (19732, 12)

# %%
# Train multi-output XGBoost
from sklearn.multioutput import MultiOutputRegressor
from xgboost import XGBRegressor

multi_model = MultiOutputRegressor(
    XGBRegressor(
        n_estimators=500,
        max_depth=8,
        learning_rate=0.05,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42,
    )
)
multi_model.fit(
    X_train,
    Y_train
)
# Out:
# MultiOutputRegressor(estimator=XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.8, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None,
#                                             feature_weights=None, gamma=None,
#                                             grow_policy=None,
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learning_rate=0.05, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=8,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=500, n_jobs=None,
#                                             num_parallel_tree=None, ...))

# %%
# Predict next hour
predictions = multi_model.predict(
    X_test
)
predictions.shape
# Out:
# (4934, 12)

# %%
# Evaluate horizon wise
from sklearn.metrics import mean_absolute_error

for step in range(12):

    mae = mean_absolute_error(
        Y_test.iloc[:, step],
        predictions[:, step]
    )
    print(
        f"Step {step+1}: MAE = {mae:.4f}"
    )


# Evaluate Entire forecast
overall_mae = mean_absolute_error(
    Y_test.values.flatten(),
    predictions.flatten()
)
print(
    f"Overall MAE: {overall_mae:.4f}"
)
# Out:
# Step 1: MAE = 1.0804
# Step 2: MAE = 1.0245
# Step 3: MAE = 1.0479
# Step 4: MAE = 1.1836
# Step 5: MAE = 1.0803
# Step 6: MAE = 1.2494
# Step 7: MAE = 1.3365
# Step 8: MAE = 1.2689
# Step 9: MAE = 1.2755
# Step 10: MAE = 1.3970
# Step 11: MAE = 1.3404
# Step 12: MAE = 1.1264
# Overall MAE: 1.2009

# %%
# Visualize one forecast window
# pick one test sample
sample_idx = 100
actual_hour = Y_test.iloc[
    sample_idx
].values
pred_hour = predictions[
    sample_idx
]
# Forecast Plot
plt.figure(figsize=(15,6))

plt.plot(
    range(1, FORECAST_HORIZON + 1),
    actual_hour,
    marker='o',
    label='Actual'
)

plt.plot(
    range(1, FORECAST_HORIZON + 1),
    pred_hour,
    marker='o',
    label='Predicted'
)

plt.title(
    f'{SERVER_NAME} | Next {FORECAST_HORIZON} Timestamp Forecast'
)

plt.xlabel('Future Timestamp')

plt.ylabel('CPU Usage (%)')

plt.legend()

plt.grid(True)

plt.show()

# %% [markdown]
# PREDICTING THE NEXT 1 HOUR FROM PREVIOUS 12 HOURS

# %%
# Create 12-hour history (144 timestamps)
HISTORY_WINDOW = 144
for lag in range(1, HISTORY_WINDOW + 1):

    df[f'cpu_lag_{lag}'] = (
        df['cpu_usage_pct']
        .shift(lag)
    )

# Create 1-hour future targets
# Predict next 1 hour
FORECAST_HORIZON = 12
for step in range(1, FORECAST_HORIZON + 1):

    df[f'target_t+{step}'] = (
        df['cpu_usage_pct']
        .shift(-step)
    )

# %%
# Remove missing rows
df_multi = df.dropna().copy()
print(df_multi.shape)
# Out:
# (24522, 245)

# %%
# Build feature list
# CPU Lag features
CPU_LAGS = [
    f'cpu_lag_{i}'
    for i in range(1, HISTORY_WINDOW + 1)
]
# Final features
FEATURES = (
    CPU_LAGS +
    [
        'memory_usage_pct',
        'power_kw',
        'cpu_temp_c',
        'inlet_temp_c',
        'cpu_change',
        'cpu_roll_mean_3',
        'cpu_volatility',
        'resource_stress_index',
        'hour_of_day',
        'day_of_week',
        'is_weekend'
    ]
)
# Create target columns
TARGETS = [

    f'target_t+{i}'

    for i in range(1, FORECAST_HORIZON + 1)

]
print(TARGETS)
# Out:
# ['target_t+1', 'target_t+2', 'target_t+3', 'target_t+4', 'target_t+5', 'target_t+6', 'target_t+7', 'target_t+8', 'target_t+9', 'target_t+10', 'target_t+11', 'target_t+12']

# %%
# Train-test split
split_index = int(
    len(df_multi) * 0.8
)
train_df = df_multi.iloc[:split_index]
test_df = df_multi.iloc[split_index:]
print(train_df.shape)
print(test_df.shape)
# Out:
# (19617, 245)
# (4905, 245)

# %%
# Sanity check
print(X_train.isna().sum().sum())
print(Y_train.isna().sum().sum())
# Out:
# 0
# 0

# %%
# Train Multi-Output XGBoost
from sklearn.multioutput import MultiOutputRegressor
from xgboost import XGBRegressor
multi_model = MultiOutputRegressor(
    XGBRegressor(
        n_estimators=300,
        max_depth=8,
        learning_rate=0.05,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42,
        tree_method='hist'
    )

)
multi_model.fit(
    X_train,
    Y_train
)
# Out:
# MultiOutputRegressor(estimator=XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.8, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None,
#                                             feature_weights=None, gamma=None,
#                                             grow_policy=None,
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learning_rate=0.05, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=8,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=300, n_jobs=None,
#                                             num_parallel_tree=None, ...))

# %%
# Predict
predictions = multi_model.predict(
    X_test
)
print(predictions.shape)
# Out:
# (4934, 12)

# %%
# Overall metrics
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)
import numpy as np
overall_mae = mean_absolute_error(
    Y_test.values.flatten(),
    predictions.flatten()

)
overall_rmse = np.sqrt(
    mean_squared_error(
        Y_test.values.flatten(),
        predictions.flatten()
    )
)
overall_r2 = r2_score(
    Y_test.values.flatten(),
    predictions.flatten()
)
print("Overall MAE :", overall_mae)
print("Overall RMSE:", overall_rmse)
print("Overall R²  :", overall_r2)
# Out:
# Overall MAE : 1.0895279097034793
# Overall RMSE: 1.5719146922771443
# Overall R²  : 0.15385497535270165

# %%
# Horizon-wise metrics
for step in range(FORECAST_HORIZON):

    mae = mean_absolute_error(
        Y_test.iloc[:, step],
        predictions[:, step]
    )
    print(
        f"Step {step+1:02d}: MAE = {mae:.4f}"
    )
# Out:
# Step 01: MAE = 0.9678
# Step 02: MAE = 0.9603
# Step 03: MAE = 1.0028
# Step 04: MAE = 1.1064
# Step 05: MAE = 1.0257
# Step 06: MAE = 1.1799
# Step 07: MAE = 1.2203
# Step 08: MAE = 1.1266
# Step 09: MAE = 1.1158
# Step 10: MAE = 1.1821
# Step 11: MAE = 1.1661
# Step 12: MAE = 1.0206

# %%
# Forecast visualization
sample_idx = 100
actual_future = Y_test.iloc[
    sample_idx
].values
pred_future = predictions[
    sample_idx
]

import matplotlib.pyplot as plt
plt.figure(figsize=(14,6))
plt.plot(
    range(1, FORECAST_HORIZON + 1),
    actual_future,
    marker='o',
    label='Actual'
)

plt.plot(
    range(1, FORECAST_HORIZON + 1),
    pred_future,
    marker='o',
    label='Predicted'
)

plt.title(
    f'{SERVER_NAME} | Past 12 Hours → Next 1 Hour Forecast'
)

plt.xlabel(
    'Future 5-Minute Intervals'
)

plt.ylabel(
    'CPU Usage (%)'
)

plt.legend()
plt.grid(True)
plt.show()
