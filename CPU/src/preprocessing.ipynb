# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Avilasha\Desktop\CPU_Predictive_Maintenance\data\Raw\host_metrics 1.csv")

# %%
# initial inspection of the data
print(df.shape)
print(df.head())
print(df.info())
# Out:
# (72750, 8)
#    id                          ts  host_id  cpu_usage_pct  memory_usage_pct  \
# 0   1  2026-04-02 12:22:07.517+00        1            4.0              74.0
# 1   2  2026-04-02 12:22:07.517+00        2           17.0              70.0
# 2   3  2026-04-02 12:22:07.517+00        3           28.0              27.0
# 3   4  2026-04-02 12:24:02.882+00        1            5.0              74.0
# 4   5  2026-04-02 12:24:02.882+00        2           16.0              70.0
#
#    power_kw  temperature_c  status
# 0     0.220           20.0  Normal
# 1     0.245           20.0  Normal
# 2     0.253           18.0  Normal
# 3     0.220           20.0  Normal
# 4     0.263           20.0  Normal
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72750 entries, 0 to 72749
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                72750 non-null  int64
# ...

# %%
# timestamp conversion
df['ts'] = pd.to_datetime(df['ts'], format='mixed', utc=True)   # converts text to datetime, 
df = df.sort_values(
    ['host_id','ts']
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 # timestamp conversion
# ----> 2 df['ts'] = pd.to_datetime(df['ts'])
#       3 df = df.sort_values(
#       4     ['host_id','ts']
#       5 )
#
# File c:\Users\Avilasha\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066             result = arg.tz_localize("utc")
#    1067 elif isinstance(arg, ABCSeries):
# -> 1068     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1069     if not cache_array.empty:
#    1070         result = arg.map(cache_array)
#
# ...
